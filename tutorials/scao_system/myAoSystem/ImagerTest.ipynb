# %%
import time
import numpy as np
import os
import sys

# 将目录添加到 Python 路径
sys.path.append('/DATACENTER5/jicheng.liu/SWJTU_OOPAO/SWJTU_OOPAO')
from OOPAO.Atmosphere import Atmosphere
from OOPAO.DeformableMirror import DeformableMirror
from OOPAO.Source import Source
from OOPAO.Telescope import Telescope
from OOPAO.ShackHartmann import ShackHartmann
from tutorials.scao_system.myAoSystem.Imager_new import Imager_new  # 导入新的科学相机模块
from tutorials.scao_system.myAoSystem.Imager import Imager # 导入之前的的科学相机模块
import matplotlib.pyplot as plt
import OOPAO.tools.displayTools as tools
# Out:
# ==================================
#      °          *      *
#  ▄██▄   ▄██▄  ▄███▄   ▄██▄ * ▄██▄
# ██* ██ ██  ██ ██  ██ ██  ██ ██  ██
# ██  ██ ██° ██ ██  ██ ██* ██ ██  ██
# ██  ██ ██  ██ ████▀  ██▄▄██ ██  ██
# ██* ██ ██  ██ ██     ██▀▀██ ██  ██
# ██  ██ ██  ██ ██ *   ██  ██ ██* ██
#  ▀██▀   ▀██▀  ██   ° ██  ██  ▀██▀
#       *         *
# ==================================
#
#
# **************************************************************************************************************************************************************
# NUMPY WARNING: mkl blas not found! Multi-threading may not work as expected.
# **************************************************************************************************************************************************************
# 1.26.2

# %%
ngs = Source(magnitude=0,optBand='H')

# 创建望远镜
tel = Telescope(resolution          = 120, # 分辨率
                diameter            = 8, # 直径
                samplingTime        = 1/1000, # 采样时间
                centralObstruction  = 0) # 中心遮挡比例
ngs * tel
atm = Atmosphere(
    telescope=tel,
    r0=0.15,  # 大气湍流的弗里德参数（Fried parameter），表示大气相干长度，单位为米
    L0=30,# 大气湍流的外尺度（Outer scale），单位为米
    altitude=[0,4000,10000],# 每个湍流层的海拔高度，单位为米
    fractionalR0=[0.7,0.25,0.05], # 每个湍流层的 Cn² 剖面，表示每个层对总湍流的贡献比例
    windSpeed=[5,10,20],# 每个湍流层的风速，单位为米/秒
    windDirection=[0,90,360])# 每个湍流层的风向，单位为度
atm.initializeAtmosphere(telescope=tel)
tel+atm
# 创建变形镜
dm=DeformableMirror(telescope    = tel,
                    nSubap       = 20, # 沿望远镜直径的变形镜驱动器数，即总驱动数=nSubap*nSubap
                    mechCoupling = 0.1) # 驱动器之间的机械耦合系数,用于描述变形镜的各个驱动器之间的机械相互作用程度
# 创建SH-WFS 

wfs = ShackHartmann(nSubap              = 20, #  沿望远镜直径的子孔径数
                    telescope           = tel,
                    lightRatio          = 0.6, # 用于筛选有效子孔径
                    is_geometric        = False, # 是否启用几何模式（直接测量梯度）
                    threshold_cog       = 0.01) # 计算光斑质心时的阈值
gainCL                  = 0.6  # 传感增益
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%% SOURCE %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#  Source Wavelength Zenith  Azimuth   Altitude Magnitude    Flux
#            [m]    [arcsec]  [deg]      [m]              [phot/m2/s]
# -------------------------------------------------------------------
#   NGS   1.654e-06    0        0        inf       -0.0   2989130434.8
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%% TELESCOPE %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#      Diameter             8                [m]
#     Resolution           120             [pixels]
#     Pixel Size           0.07              [m]
#      Surface             50.0              [m2]
# Central Obstruction        0          [% of diameter]
# Pixels in the pupil      11304            [pixels]
#       Source             None
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# No light propagated through the telescope
# -> Computing the initial phase screen...
# initial phase screen : 0.008581161499023438 s
# ZZt.. : 3.17160964012146 s
# ZXt.. : 0.288071870803833 s
# XXt.. : 0.14998865127563477 s
# Done!
# -> Computing the initial phase screen...
# initial phase screen : 0.008070945739746094 s
# ZZt.. : 1.6689300537109375e-06 s
# ZXt.. : 3.62396240234375e-05 s
# XXt.. : 7.62939453125e-06 s
# SCAO system considered: covariance matrices were already computed!
# Done!
# -> Computing the initial phase screen...
# initial phase screen : 0.013579130172729492 s
# ZZt.. : 2.384185791015625e-06 s
# ZXt.. : 3.170967102050781e-05 s
# XXt.. : 9.775161743164062e-06 s
# SCAO system considered: covariance matrices were already computed!
# Done!
# No coordinates loaded.. taking the cartesian geometry as a default
# Generating a Deformable Mirror:
# Computing the 2D zonal modes...
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%% DEFORMABLE MIRROR %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Controlled Actuators        357
#          M4                False
#         Pitch               0.4               [m]
#  Mechanical Coupling        0.1               [%]
# -------------------------------------------------------------------------------
# Mis-registration:
# Rotation [deg]	Shift X [m]	Shift Y [m]	Radial Scaling [%]	Tangential Scaling [%]
#       0       	     0     	     0     	        0         	          0
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Selecting valid subapertures based on flux considerations..

# %%
src = Source(magnitude=5,optBand='I')
src*tel
print(tel.OPD.shape)
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%% SOURCE %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#  Source Wavelength Zenith  Azimuth   Altitude Magnitude    Flux
#            [m]    [arcsec]  [deg]      [m]              [phot/m2/s]
# -------------------------------------------------------------------
#   NGS    7.9e-07     0        0        inf       5.0    73369565.2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# (120, 120)

# %%
cam = Imager(nyquist_sampling=2,field_stop_size=30,exposure_time=10,clock_rate=0.1)
cam.relay(tel.src)
cam.display()

# %%
tel-atm
camH = Imager_new(diameter=tel.D,nyquist_sampling=2,field_stop_size=30,exposure_time=1,clock_rate=1) # 创建科学相机
'''新的图像分辨率为nyquist_sampling*field_stop_size*2'''


camH.relay(tel.src)
camH.imagesc()

# %%
src*tel
camH.relay(src)
camH.referenceFrame = camH.frame 
camH.imagesc()
print(camH.resolution)
# Out:
# 120

# %%
print(camH.strehl)
tel+atm
camH.relay(src)
camH.referenceFrame = camH.frame 
camH.imagesc()
camH.exposureTime=10
# Out:
# None

# %%
atm.update()
camH.relay(tel.src)
camH.imagesc()
print(camH.strehl)
'''新的SR是二维，直接取camH.strehl[0][0]就行'''
# Out:
# 没有图像可以显示。请先运行 'relay' 方法。
# None
# '新的SR是二维，直接取camH.strehl[0][0]就行'

# %%
from OOPAO.calibration.ao_calibration import ao_calibration
from tutorials.scao_system.parameter_files.parameterFile_VLT_I_Band_SHWFS import initializeParameterFile

param = initializeParameterFile()

'''
加载或生成模态基,即模式到控制矩阵（M2C）用于将模式映射到变形镜（DM）的控制信号
计算或加载交互矩阵
'''
ao_calib =  ao_calibration(param            = param,\
                           ngs              = ngs,\
                           tel              = tel,\
                           atm              = atm,\
                           dm               = dm,\
                           wfs              = wfs,\
                           nameFolderIntMat = None,\
                           nameIntMat       = None,\
                           nameFolderBasis  = None,\
                           nameBasis        = None,\
                           nMeasurements    = 100)
# Out:
# Reading/Writting calibration data from data_calibration/
# Writting output data in data_cl/
# Loading the KL Modal Basis from: data_calibration/M2C_120_res
# ERROR: No file found! Taking a zonal basis instead..
# Loading Interaction matrix data_calibration/VLT_I_band_20x20/zonal_interaction_matrix_120_res_308_subap_diffractive...
# ERROR: No file found! computing imat..
# Interaction Matrix Computation:
#  25%|██▌       | 1/4 [00:02<00:08,  2.74s/it]
# 100/357
# Time elapsed: 2.740252733230591 s
#  50%|█████     | 2/4 [00:05<00:05,  2.69s/it]
# 200/357
# Time elapsed: 2.6497979164123535 s
#  75%|███████▌  | 3/4 [00:08<00:02,  2.80s/it]
# 300/357
# Time elapsed: 2.9356906414031982 s
# 100%|██████████| 4/4 [00:10<00:00,  2.50s/it]
# 400/357
# Time elapsed: 1.6765992641448975 s
# No Modal Gains found. All gains set to 1

# %%
print(ngs.phase.shape,ngs.fluxMap.shape)
# Out:
# (120, 120, 57) (120, 120)

# %%
camH.relay(tel.src)
# Out:
# fluxMap: (120, 120)
# src.phase: (120, 120, 57)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[142], line 1
# ----> 1 camH.relay(tel.src)
#
# File /DATACENTER5/jicheng.liu/SWJTU_OOPAO/SWJTU_OOPAO/tutorials/scao_system/myAoSystem/Imager_new.py:104, in Imager_new.relay(self, src)
#      97 def relay(self, src):
#      98     """
#      99     将光源通过镜头阵列传递，并触发图像数据处理。
#     100
#     101     Args:
#     102         src (object): 源对象。
#     103     """
# --> 104     self.imgLens.relay(clockRate=self.clockRate, src=src)
#     105     # plt.imshow(self.imgLens.imagelets)
#     106     # 将 imgLens 的图像数据传递给 readout 方法
#     107     self.readOut(self.imgLens.imagelets)
#
# File /DATACENTER5/jicheng.liu/SWJTU_OOPAO/SWJTU_OOPAO/tutorials/scao_system/myAoSystem/lensletArray.py:140, in lensletArray.relay(self, src, clockRate)
#     136 def relay(self, src, clockRate):
#     137     """
#     138     继电器，将光源传递给 propagate_through 方法并计算 imagelets。
#     139     """
# --> 140     wave_prgted = self.propagate_through(clockRate, src=src)
#     141     # 计算强度
#     142     self.imagelets = np.abs(wave_prgted)**2 * self.throughput
#
# File /DATACENTER5/jicheng.liu/SWJTU_OOPAO/SWJTU_OOPAO/tutorials/scao_system/myAoSystem/lensletArray.py:218, in lensletArray.propagate_through(self, clockRate, src, data)
#     216     print("src.phase:",src.phase.shape)
#     217     amplitude = np.sqrt(src.fluxMap/clockRate)
# --> 218     val = amplitude * np.exp(1j * src.phase)
#     219 else:
#     220     print("错误：必须提供一个 Source 对象或一个数据数组。")
#
# ValueError: operands could not be broadcast together with shapes (120,120) (120,120,57)

# %%
dm.coefs = 0
tel+atm
ngs*tel*dm*wfs
camH.relay(tel.src)

# %%
ngs.magnitude=10

# %%
camH1 = Imager(diameter=tel.D,nyquist_sampling=4,field_stop_size=20,exposure_time=1,clock_rate=1)
camH2 = Imager_new(diameter=tel.D,nyquist_sampling=4,field_stop_size=20,exposure_time=1,clock_rate=1)
print(camH2.referenceFrame,camH2.frame,camH2.strehl)
# 闭环控制
calib_CL    = ao_calib.calib # 交互矩阵
M2C_CL      = ao_calib.M2C
dm.coefs=0
tel+atm
ngs*tel*dm*wfs
# initialize DM commands

camH2.relay(tel.src)
param['nLoop'] = 100

wfs.cam.photonNoise = True  # 启用光子噪声
atm.initializeAtmosphere(telescope=tel)
# 分配内存以保存数据
SR_camH1 = np.zeros(param['nLoop'])  # 斯特列尔比
SR_camH2 = np.zeros(param['nLoop'])  # 斯特列尔比
SR_old = np.zeros(param['nLoop'])  # 近似方式斯特列尔比
total = np.zeros(param['nLoop'])  # 总波前误差
residual = np.zeros(param['nLoop'])  # 残余波前误差
wfsSignal = np.zeros(wfs.nSignal)  # 波前传感器信号

# 初始化变形镜控制信号
dm.coefs = 0
gainCL = 0.6  # 闭环控制增益
# 主循环
for i in range(param['nLoop']):
    start_time = time.time()

    # 更新大气湍流相位屏
    atm.update()

    tel-atm
    camH1.relay(tel.src)
    camH1.reference_frame = camH1.frame
    camH2.relay(tel.src)
    camH2.referenceFrame = camH2.frame
    tel+atm

    # 记录总的波前误差
    total[i] = np.std(tel.OPD[np.where(tel.pupil > 0)]) * 1e9

    # 光波传播：自然引导星 -> 望远镜 -> 变形镜 -> 波前传感器
    ngs * tel * dm * wfs
    # 更新变形镜控制信号
    dm.coefs = dm.coefs - gainCL * M2C_CL @ calib_CL.M @ wfsSignal

    # 更新波前传感器信号
    wfsSignal = wfs.signal
    # 记录残余波前误差
    residual[i] = np.std(tel.OPD[np.where(tel.pupil > 0)]) * 1e9
    
    camH1.relay(tel.src)
    camH2.relay(tel.src)
    

    SR_camH1[i] = camH1.strehl  # 科学相机计算的斯特列尔比
    SR_camH2[i] = camH2.strehl
    SR_old[i]=np.exp(-np.var(tel.src.phase[np.where(tel.pupil==1)]))


    # 打印结果
    elapsed_time = time.time() - start_time
    print(f'Loop {i+1}/{param["nLoop"]} - SR_camH1: {SR_camH1[i]:.2f},SR_camH2:{SR_camH2[i]:.2f},SR_old:{SR_old[i]:.2f}')
    # print(f'Turbulence: {total[i]:.2f} nm -- Residual: {residual[i]:.2f} nm -- SR: {SR_camH1[i]:.2f}\n')


# 绘制斯特列尔比随时间的变化

plt.figure()
plt.plot(np.arange(param['nLoop']), SR_camH1, label='old imager Strehl Ratio')
plt.plot(np.arange(param['nLoop']), SR_camH2, label='new imager Strehl Ratio')
plt.plot(np.arange(param['nLoop']), SR_old, label='Strehl Ratio(Approximate approach)')
plt.xlabel('Loop Index')
plt.ylabel('Strehl Ratio')

plt.legend()
plt.grid()
plt.show()
# Out:
# None None None
# /tmp/ipykernel_2884516/4247184709.py:60: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   SR_camH2[i] = camH2.strehl
# Loop 1/100 - SR_camH1: 0.26,SR_camH2:0.29,SR_old:0.00
# Loop 2/100 - SR_camH1: 0.26,SR_camH2:0.29,SR_old:0.00
# Loop 3/100 - SR_camH1: 0.39,SR_camH2:0.42,SR_old:0.12
# Loop 4/100 - SR_camH1: 0.72,SR_camH2:0.75,SR_old:0.46
# Loop 5/100 - SR_camH1: 0.48,SR_camH2:0.51,SR_old:0.21
# Loop 6/100 - SR_camH1: 0.57,SR_camH2:0.60,SR_old:0.31
# Loop 7/100 - SR_camH1: 0.73,SR_camH2:0.76,SR_old:0.48
# Loop 8/100 - SR_camH1: 0.71,SR_camH2:0.75,SR_old:0.45
# Loop 9/100 - SR_camH1: 0.70,SR_camH2:0.72,SR_old:0.47
# Loop 10/100 - SR_camH1: 0.78,SR_camH2:0.78,SR_old:0.60
# Loop 11/100 - SR_camH1: 0.85,SR_camH2:0.85,SR_old:0.70
# Loop 12/100 - SR_camH1: 0.86,SR_camH2:0.87,SR_old:0.72
# Loop 13/100 - SR_camH1: 0.85,SR_camH2:0.86,SR_old:0.70
# Loop 14/100 - SR_camH1: 0.81,SR_camH2:0.83,SR_old:0.61
# Loop 15/100 - SR_camH1: 0.77,SR_camH2:0.80,SR_old:0.54
# Loop 16/100 - SR_camH1: 0.79,SR_camH2:0.81,SR_old:0.58
# Loop 17/100 - SR_camH1: 0.83,SR_camH2:0.84,SR_old:0.65
# Loop 18/100 - SR_camH1: 0.84,SR_camH2:0.85,SR_old:0.68
# Loop 19/100 - SR_camH1: 0.85,SR_camH2:0.86,SR_old:0.70
# Loop 20/100 - SR_camH1: 0.85,SR_camH2:0.86,SR_old:0.70
# Loop 21/100 - SR_camH1: 0.85,SR_camH2:0.85,SR_old:0.70
# Loop 22/100 - SR_camH1: 0.84,SR_camH2:0.85,SR_old:0.69
# Loop 23/100 - SR_camH1: 0.85,SR_camH2:0.86,SR_old:0.70
# Loop 24/100 - SR_camH1: 0.85,SR_camH2:0.86,SR_old:0.71
# Loop 25/100 - SR_camH1: 0.85,SR_camH2:0.86,SR_old:0.71
# Loop 26/100 - SR_camH1: 0.85,SR_camH2:0.86,SR_old:0.71
# Loop 27/100 - SR_camH1: 0.85,SR_camH2:0.85,SR_old:0.70
# Loop 28/100 - SR_camH1: 0.84,SR_camH2:0.85,SR_old:0.69
# Loop 29/100 - SR_camH1: 0.84,SR_camH2:0.85,SR_old:0.68
# Loop 30/100 - SR_camH1: 0.85,SR_camH2:0.85,SR_old:0.69
# Loop 31/100 - SR_camH1: 0.85,SR_camH2:0.86,SR_old:0.70
# Loop 32/100 - SR_camH1: 0.85,SR_camH2:0.86,SR_old:0.71
# Loop 33/100 - SR_camH1: 0.85,SR_camH2:0.86,SR_old:0.71
# Loop 34/100 - SR_camH1: 0.85,SR_camH2:0.86,SR_old:0.70
# Loop 35/100 - SR_camH1: 0.85,SR_camH2:0.85,SR_old:0.67
# Loop 36/100 - SR_camH1: 0.84,SR_camH2:0.85,SR_old:0.65
# Loop 37/100 - SR_camH1: 0.83,SR_camH2:0.84,SR_old:0.62
# Loop 38/100 - SR_camH1: 0.81,SR_camH2:0.83,SR_old:0.57
# Loop 39/100 - SR_camH1: 0.80,SR_camH2:0.82,SR_old:0.54
# Loop 40/100 - SR_camH1: 0.80,SR_camH2:0.82,SR_old:0.53
# Loop 41/100 - SR_camH1: 0.80,SR_camH2:0.82,SR_old:0.52
# Loop 42/100 - SR_camH1: 0.80,SR_camH2:0.82,SR_old:0.52
# Loop 43/100 - SR_camH1: 0.81,SR_camH2:0.83,SR_old:0.55
# Loop 44/100 - SR_camH1: 0.82,SR_camH2:0.84,SR_old:0.57
# Loop 45/100 - SR_camH1: 0.82,SR_camH2:0.84,SR_old:0.58
# Loop 46/100 - SR_camH1: 0.83,SR_camH2:0.84,SR_old:0.58
# Loop 47/100 - SR_camH1: 0.83,SR_camH2:0.84,SR_old:0.57
# Loop 48/100 - SR_camH1: 0.83,SR_camH2:0.85,SR_old:0.58
# Loop 49/100 - SR_camH1: 0.85,SR_camH2:0.86,SR_old:0.61
# Loop 50/100 - SR_camH1: 0.85,SR_camH2:0.86,SR_old:0.62
# Loop 51/100 - SR_camH1: 0.86,SR_camH2:0.86,SR_old:0.63
# Loop 52/100 - SR_camH1: 0.85,SR_camH2:0.86,SR_old:0.63
# Loop 53/100 - SR_camH1: 0.85,SR_camH2:0.86,SR_old:0.63
# Loop 54/100 - SR_camH1: 0.85,SR_camH2:0.85,SR_old:0.62
# Loop 55/100 - SR_camH1: 0.85,SR_camH2:0.85,SR_old:0.63
# Loop 56/100 - SR_camH1: 0.85,SR_camH2:0.85,SR_old:0.64
# Loop 57/100 - SR_camH1: 0.85,SR_camH2:0.85,SR_old:0.66
# Loop 58/100 - SR_camH1: 0.85,SR_camH2:0.85,SR_old:0.69
# Loop 59/100 - SR_camH1: 0.85,SR_camH2:0.85,SR_old:0.69
# Loop 60/100 - SR_camH1: 0.83,SR_camH2:0.83,SR_old:0.66
# Loop 61/100 - SR_camH1: 0.80,SR_camH2:0.81,SR_old:0.60
# Loop 62/100 - SR_camH1: 0.76,SR_camH2:0.78,SR_old:0.52
# Loop 63/100 - SR_camH1: 0.76,SR_camH2:0.78,SR_old:0.52
# Loop 64/100 - SR_camH1: 0.77,SR_camH2:0.79,SR_old:0.56
# Loop 65/100 - SR_camH1: 0.78,SR_camH2:0.80,SR_old:0.58
# Loop 66/100 - SR_camH1: 0.78,SR_camH2:0.80,SR_old:0.58
# Loop 67/100 - SR_camH1: 0.78,SR_camH2:0.79,SR_old:0.57
# Loop 68/100 - SR_camH1: 0.76,SR_camH2:0.78,SR_old:0.54
# Loop 69/100 - SR_camH1: 0.75,SR_camH2:0.78,SR_old:0.53
# Loop 70/100 - SR_camH1: 0.74,SR_camH2:0.77,SR_old:0.50
# Loop 71/100 - SR_camH1: 0.74,SR_camH2:0.76,SR_old:0.48
# Loop 72/100 - SR_camH1: 0.73,SR_camH2:0.76,SR_old:0.48
# Loop 73/100 - SR_camH1: 0.75,SR_camH2:0.77,SR_old:0.50
# Loop 74/100 - SR_camH1: 0.76,SR_camH2:0.78,SR_old:0.53
# Loop 75/100 - SR_camH1: 0.77,SR_camH2:0.78,SR_old:0.55
# Loop 76/100 - SR_camH1: 0.77,SR_camH2:0.79,SR_old:0.56
# Loop 77/100 - SR_camH1: 0.78,SR_camH2:0.79,SR_old:0.60
# Loop 78/100 - SR_camH1: 0.79,SR_camH2:0.80,SR_old:0.61
# Loop 79/100 - SR_camH1: 0.80,SR_camH2:0.80,SR_old:0.63
# Loop 80/100 - SR_camH1: 0.81,SR_camH2:0.81,SR_old:0.65
# Loop 81/100 - SR_camH1: 0.81,SR_camH2:0.82,SR_old:0.66
# Loop 82/100 - SR_camH1: 0.81,SR_camH2:0.82,SR_old:0.67
# Loop 83/100 - SR_camH1: 0.81,SR_camH2:0.82,SR_old:0.66
# Loop 84/100 - SR_camH1: 0.80,SR_camH2:0.81,SR_old:0.64
# Loop 85/100 - SR_camH1: 0.79,SR_camH2:0.80,SR_old:0.60
# Loop 86/100 - SR_camH1: 0.78,SR_camH2:0.80,SR_old:0.57
# Loop 87/100 - SR_camH1: 0.78,SR_camH2:0.80,SR_old:0.56
# Loop 88/100 - SR_camH1: 0.77,SR_camH2:0.79,SR_old:0.55
# Loop 89/100 - SR_camH1: 0.78,SR_camH2:0.80,SR_old:0.56
# Loop 90/100 - SR_camH1: 0.78,SR_camH2:0.80,SR_old:0.54
# Loop 91/100 - SR_camH1: 0.76,SR_camH2:0.79,SR_old:0.49
# Loop 92/100 - SR_camH1: 0.76,SR_camH2:0.79,SR_old:0.48
# Loop 93/100 - SR_camH1: 0.77,SR_camH2:0.79,SR_old:0.50
# Loop 94/100 - SR_camH1: 0.77,SR_camH2:0.79,SR_old:0.50
# Loop 95/100 - SR_camH1: 0.77,SR_camH2:0.79,SR_old:0.50
# Loop 96/100 - SR_camH1: 0.77,SR_camH2:0.79,SR_old:0.49
# Loop 97/100 - SR_camH1: 0.78,SR_camH2:0.80,SR_old:0.50
# Loop 98/100 - SR_camH1: 0.79,SR_camH2:0.81,SR_old:0.50
# Loop 99/100 - SR_camH1: 0.80,SR_camH2:0.82,SR_old:0.51
# Loop 100/100 - SR_camH1: 0.79,SR_camH2:0.81,SR_old:0.51

# %%
tel+atm
ngs*tel*dm*wfs
camH2.relay(tel.src)
# Out:
# fluxMap: (120, 120)
# src.phase: (120, 120)

# %% [markdown]
# WFE 法（绿色） 提供了一个理论上的、相对平滑的性能指标，适合于初步估算。
#
# 图像峰值法（蓝色） 对瞬时性能非常敏感，波动性大，可能无法准确反映系统的平均性能。
#
# OTF 积分法（橙色） 提供了一个更鲁棒、更全面的性能评估，它将所有重要的物理效应都考虑在内，因此其结果最能代表系统的真实性能。

# %%
'''
曝光时间大于采样间隔（帧频的倒数）的情况：比如帧频为1，曝光时间为2s，就需要采样两次才能形成一张图片，
即采样exposure_time*clock_rate次形成一张图片，计算一次SR
问题：如果exposure_time和clock_rate不对应的话不能保证每一步都有图像和SR
'''

# camH1 = Imager(diameter=tel.D,nyquist_sampling=4,field_stop_size=20,exposure_time=1,clock_rate=1)
camH2 = Imager_new(diameter=tel.D,nyquist_sampling=4,field_stop_size=20,exposure_time=4,clock_rate=1)
print(camH2.referenceFrame,camH2.frame,camH2.strehl)
# 闭环控制
calib_CL    = ao_calib.calib # 交互矩阵
M2C_CL      = ao_calib.M2C

tel+atm
ngs*tel*dm*wfs
# initialize DM commands
dm.coefs=0


param['nLoop'] = 200

wfs.cam.photonNoise = True  # 启用光子噪声
atm.initializeAtmosphere(telescope=tel)
# 分配内存以保存数据
SR_camH1 = np.zeros(param['nLoop'])  # 斯特列尔比
SR_camH2 = np.zeros(param['nLoop'])  # 斯特列尔比
SR_old = np.zeros(param['nLoop'])  # 近似方式斯特列尔比
total = np.zeros(param['nLoop'])  # 总波前误差
residual = np.zeros(param['nLoop'])  # 残余波前误差
wfsSignal = np.zeros(wfs.nSignal)  # 波前传感器信号
SR = []
# 初始化变形镜控制信号
dm.coefs = 0
gainCL = 0.6  # 闭环控制增益
# 主循环
'''只在循环前得到referenceFrame（不知道还会不会出现SR>1的情况）'''
tel-atm
num_ref_frames = int(camH2.exposureTime * camH2.clockRate)
for _ in range(num_ref_frames):
    # 用理想的 ngs 进行一次“传递”，获取图像
    camH2.relay(ngs)

# 将累积好的帧设置为参考帧
camH2.referenceFrame = camH2.frame
tel+atm
for i in range(param['nLoop']):
    start_time = time.time()

    # 更新大气湍流相位屏
    atm.update()

    # 记录总的波前误差
    total[i] = np.std(tel.OPD[np.where(tel.pupil > 0)]) * 1e9

    # 光波传播：自然引导星 -> 望远镜 -> 变形镜 -> 波前传感器
    ngs * tel * dm * wfs
    # 更新变形镜控制信号
    dm.coefs = dm.coefs - gainCL * M2C_CL @ calib_CL.M @ wfsSignal

    # 更新波前传感器信号
    wfsSignal = wfs.signal
    # 记录残余波前误差
    residual[i] = np.std(tel.OPD[np.where(tel.pupil > 0)]) * 1e9

    camH2.relay(ngs)
    print(camH2.strehl)
        # 检查是否完成了一次完整曝光
    if camH2.frame is not None:
        # imager_cam.frame 包含了累积后的图像
        # 可以在这里保存图像，或者进行额外的分析
        print(f"在闭环周期 {i+1} 采集到一帧 imager 图像。")
        SR.append(camH2.strehl[0][0])
        print('SR:', camH2.strehl[0][0])


# 绘制斯特列尔比随时间的变化

plt.figure()
# plt.plot(np.arange(param['nLoop']), SR_camH1, label='old imager Strehl Ratio')
plt.plot(np.arange(param['nLoop']/camH2.exposureTime), SR, label='new imager Strehl Ratio')
# plt.plot(np.arange(param['nLoop']), SR_old, label='Strehl Ratio(Approximate approach)')
plt.xlabel('Loop Index')
plt.ylabel('Strehl Ratio')
plt.title(  f"gainCL={gainCL:.2f}, "
            f"samplingTime={tel.samplingTime:.3f}s\n"
            f"exposure_time={camH.exposureTime:.3f}s, "
            f"clock_rate={camH.clockRate:.0f}Hz")
plt.legend()
plt.grid()
plt.show()
# Out:
# None None None
# fluxMap: (120, 120)
# src.phase: (120, 120)
# fluxMap: (120, 120)
# src.phase: (120, 120)
# fluxMap: (120, 120)
# src.phase: (120, 120)
# fluxMap: (120, 120)
# src.phase: (120, 120)
# fluxMap: (120, 120)
# src.phase: (120, 120)
# None
# fluxMap: (120, 120)
# src.phase: (120, 120)
# None
# fluxMap: (120, 120)
# src.phase: (120, 120)
# None
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.25575731]]
# 在闭环周期 4 采集到一帧 imager 图像。
# SR: 0.2557573053020219
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.25575731]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.25575731]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.25575731]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.54503936]]
# 在闭环周期 8 采集到一帧 imager 图像。
# SR: 0.5450393613823203
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.54503936]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.54503936]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.54503936]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.77396506]]
# 在闭环周期 12 采集到一帧 imager 图像。
# SR: 0.7739650566633189
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.77396506]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.77396506]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.77396506]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.82452223]]
# 在闭环周期 16 采集到一帧 imager 图像。
# SR: 0.8245222325939745
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.82452223]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.82452223]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.82452223]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.8503941]]
# 在闭环周期 20 采集到一帧 imager 图像。
# SR: 0.8503940954491429
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.8503941]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.8503941]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.8503941]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.84938121]]
# 在闭环周期 24 采集到一帧 imager 图像。
# SR: 0.8493812101524648
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.84938121]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.84938121]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.84938121]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.85454807]]
# 在闭环周期 28 采集到一帧 imager 图像。
# SR: 0.8545480731163584
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.85454807]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.85454807]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.85454807]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.85329845]]
# 在闭环周期 32 采集到一帧 imager 图像。
# SR: 0.8532984463202802
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.85329845]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.85329845]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.85329845]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.85256133]]
# 在闭环周期 36 采集到一帧 imager 图像。
# SR: 0.8525613274845691
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.85256133]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.85256133]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.85256133]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.82292227]]
# 在闭环周期 40 采集到一帧 imager 图像。
# SR: 0.8229222665740752
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.82292227]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.82292227]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.82292227]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.83416515]]
# 在闭环周期 44 采集到一帧 imager 图像。
# SR: 0.8341651531843842
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.83416515]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.83416515]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.83416515]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.83713271]]
# 在闭环周期 48 采集到一帧 imager 图像。
# SR: 0.8371327107025276
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.83713271]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.83713271]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.83713271]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.85338047]]
# 在闭环周期 52 采集到一帧 imager 图像。
# SR: 0.8533804717713369
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.85338047]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.85338047]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.85338047]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.85124897]]
# 在闭环周期 56 采集到一帧 imager 图像。
# SR: 0.8512489720619814
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.85124897]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.85124897]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.85124897]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.84208557]]
# 在闭环周期 60 采集到一帧 imager 图像。
# SR: 0.8420855719386958
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.84208557]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.84208557]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.84208557]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.79640601]]
# 在闭环周期 64 采集到一帧 imager 图像。
# SR: 0.7964060116884268
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.79640601]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.79640601]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.79640601]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.79024224]]
# 在闭环周期 68 采集到一帧 imager 图像。
# SR: 0.7902422424524405
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.79024224]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.79024224]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.79024224]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.76026031]]
# 在闭环周期 72 采集到一帧 imager 图像。
# SR: 0.7602603120728927
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.76026031]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.76026031]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.76026031]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.78153827]]
# 在闭环周期 76 采集到一帧 imager 图像。
# SR: 0.7815382694572596
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.78153827]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.78153827]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.78153827]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.80059377]]
# 在闭环周期 80 采集到一帧 imager 图像。
# SR: 0.8005937693481517
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.80059377]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.80059377]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.80059377]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.80499573]]
# 在闭环周期 84 采集到一帧 imager 图像。
# SR: 0.8049957262097209
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.80499573]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.80499573]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.80499573]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.79885819]]
# 在闭环周期 88 采集到一帧 imager 图像。
# SR: 0.7988581880145061
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.79885819]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.79885819]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.79885819]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.78841742]]
# 在闭环周期 92 采集到一帧 imager 图像。
# SR: 0.7884174171977693
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.78841742]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.78841742]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.78841742]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.78128003]]
# 在闭环周期 96 采集到一帧 imager 图像。
# SR: 0.7812800271003302
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.78128003]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.78128003]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.78128003]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.80473293]]
# 在闭环周期 100 采集到一帧 imager 图像。
# SR: 0.8047329268737815
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.80473293]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.80473293]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.80473293]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.79263525]]
# 在闭环周期 104 采集到一帧 imager 图像。
# SR: 0.7926352481619909
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.79263525]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.79263525]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.79263525]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.80234919]]
# 在闭环周期 108 采集到一帧 imager 图像。
# SR: 0.8023491856663431
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.80234919]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.80234919]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.80234919]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.82363383]]
# 在闭环周期 112 采集到一帧 imager 图像。
# SR: 0.8236338304122127
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.82363383]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.82363383]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.82363383]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.84768942]]
# 在闭环周期 116 采集到一帧 imager 图像。
# SR: 0.8476894214037958
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.84768942]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.84768942]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.84768942]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.78201719]]
# 在闭环周期 120 采集到一帧 imager 图像。
# SR: 0.7820171943112127
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.78201719]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.78201719]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.78201719]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.7868154]]
# 在闭环周期 124 采集到一帧 imager 图像。
# SR: 0.7868154047471735
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.7868154]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.7868154]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.7868154]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.77960481]]
# 在闭环周期 128 采集到一帧 imager 图像。
# SR: 0.7796048052855928
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.77960481]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.77960481]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.77960481]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.8134162]]
# 在闭环周期 132 采集到一帧 imager 图像。
# SR: 0.8134161972809881
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.8134162]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.8134162]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.8134162]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.84178329]]
# 在闭环周期 136 采集到一帧 imager 图像。
# SR: 0.8417832863422154
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.84178329]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.84178329]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.84178329]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.77059439]]
# 在闭环周期 140 采集到一帧 imager 图像。
# SR: 0.7705943850939841
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.77059439]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.77059439]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.77059439]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.72389002]]
# 在闭环周期 144 采集到一帧 imager 图像。
# SR: 0.7238900181990943
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.72389002]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.72389002]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.72389002]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.77154932]]
# 在闭环周期 148 采集到一帧 imager 图像。
# SR: 0.7715493153220236
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.77154932]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.77154932]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.77154932]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.78322414]]
# 在闭环周期 152 采集到一帧 imager 图像。
# SR: 0.7832241401844969
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.78322414]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.78322414]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.78322414]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.81646931]]
# 在闭环周期 156 采集到一帧 imager 图像。
# SR: 0.8164693078720313
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.81646931]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.81646931]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.81646931]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.82906515]]
# 在闭环周期 160 采集到一帧 imager 图像。
# SR: 0.8290651528062559
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.82906515]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.82906515]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.82906515]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.84127057]]
# 在闭环周期 164 采集到一帧 imager 图像。
# SR: 0.8412705731090436
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.84127057]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.84127057]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.84127057]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.85158026]]
# 在闭环周期 168 采集到一帧 imager 图像。
# SR: 0.8515802615724023
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.85158026]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.85158026]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.85158026]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.85247607]]
# 在闭环周期 172 采集到一帧 imager 图像。
# SR: 0.8524760742801943
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.85247607]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.85247607]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.85247607]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.84077597]]
# 在闭环周期 176 采集到一帧 imager 图像。
# SR: 0.8407759728332352
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.84077597]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.84077597]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.84077597]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.85642641]]
# 在闭环周期 180 采集到一帧 imager 图像。
# SR: 0.8564264055155085
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.85642641]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.85642641]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.85642641]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.83922388]]
# 在闭环周期 184 采集到一帧 imager 图像。
# SR: 0.8392238785723373
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.83922388]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.83922388]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.83922388]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.7610824]]
# 在闭环周期 188 采集到一帧 imager 图像。
# SR: 0.7610823997020133
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.7610824]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.7610824]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.7610824]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.69435284]]
# 在闭环周期 192 采集到一帧 imager 图像。
# SR: 0.6943528405680238
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.69435284]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.69435284]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.69435284]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.69060989]]
# 在闭环周期 196 采集到一帧 imager 图像。
# SR: 0.6906098870562627
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.69060989]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.69060989]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.69060989]]
# fluxMap: (120, 120)
# src.phase: (120, 120)
# [[0.62886785]]
# 在闭环周期 200 采集到一帧 imager 图像。
# SR: 0.6288678472758948
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
print(wfs.signal.max())
print(dm.coefs.max())
# Out:
# 6.7695108871994e-07
# 4.943606535624121e-06

# %%
print(camH2.frame[...,None].shape)
print(np.zeros([160,160,1]).shape)
# Out:
# (160, 160, 1)
# (160, 160, 1)

# %%
camH2.frame / (camH2.frame.max())
# Out:
# array([[4.56870994e+08, 4.84007385e+08, 5.13806617e+08, ...,
#         1.08086634e+09, 1.03765143e+09, 9.37558816e+08],
#        [7.21876459e+08, 7.78917917e+08, 7.95326410e+08, ...,
#         1.21436976e+09, 1.19610258e+09, 1.11722402e+09],
#        [1.09478481e+09, 1.13687596e+09, 1.09897737e+09, ...,
#         1.29497387e+09, 1.30658640e+09, 1.26128826e+09],
#        ...,
#        [5.63411417e+08, 7.83330769e+08, 1.03736143e+09, ...,
#         6.67848824e+08, 7.23248892e+08, 7.53220100e+08],
#        [6.90353872e+08, 9.26896891e+08, 1.19617239e+09, ...,
#         5.85895299e+08, 6.21494767e+08, 6.36307064e+08],
#        [8.15205525e+08, 1.07049281e+09, 1.35779496e+09, ...,
#         4.90834765e+08, 5.09079345e+08, 5.11655171e+08]])

# %%
camH.exposureTime = 1
camH.clockRate = 1
camH.relay(ngs)
referenceFrame = camH.referenceFrame
frame = camH.frame
print(frame,camH.frameCount,camH.clockRate)
# Out:
# [[9.64688668e+07 9.52187289e+07 9.41771296e+07 ... 2.90574273e+08
#   2.75216436e+08 2.58754292e+08]
#  [1.12726227e+08 1.12354997e+08 1.11839550e+08 ... 3.06791632e+08
#   2.91648650e+08 2.75338799e+08]
#  [1.32124732e+08 1.32264081e+08 1.31909623e+08 ... 3.22107078e+08
#   3.07383655e+08 2.91453615e+08]
#  ...
#  [1.95337208e+08 2.29046174e+08 2.64641336e+08 ... 1.47511632e+08
#   1.49317112e+08 1.50690517e+08]
#  [1.98016931e+08 2.32342378e+08 2.68649628e+08 ... 1.37377765e+08
#   1.39102943e+08 1.40450447e+08]
#  [2.00333791e+08 2.35224412e+08 2.72201619e+08 ... 1.27308627e+08
#   1.28971297e+08 1.30309702e+08]] 0 1

# %%
plt.subplot(1,2,1)
plt.imshow(referenceFrame, cmap='pink', origin='lower')
plt.title('Imager Frame')
plt.xlabel('X Pixels')
plt.ylabel('Y Pixels')

plt.subplot(1,2,2)
plt.imshow(frame, cmap='pink', origin='lower')
plt.title('Imager Frame')
plt.xlabel('X Pixels')
plt.ylabel('Y Pixels')
plt.show()

# %%
from skimage.transform import resize
referenceFrame = resize(referenceFrame, (128,128), mode='reflect', anti_aliasing=True)
frame = resize(frame, (128,128), mode='reflect', anti_aliasing=True)
plt.subplot(1,2,1)
plt.imshow(referenceFrame, cmap='pink', origin='lower')
plt.title('Imager Frame')
plt.xlabel('X Pixels')
plt.ylabel('Y Pixels')

plt.subplot(1,2,2)
plt.imshow(frame, cmap='pink', origin='lower')
plt.title('Imager Frame')
plt.xlabel('X Pixels')
plt.ylabel('Y Pixels')
plt.show()

# %%
wfs.signal.shape[0]
# Out:
# 616

# %%
dm.coefs.shape[0]
# Out:
# 357
