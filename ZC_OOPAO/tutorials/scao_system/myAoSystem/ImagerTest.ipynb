# %% [markdown]
# # 25.04.03修改耦合mechCoupling=0.45->0.1

# %%
import time
import numpy as np
import os
import sys
# 将目录添加到 Python 路径
sys.path.append('/DATACENTER4/jiangbo.chai/SWJTU_OOPAO')
from OOPAO.Atmosphere import Atmosphere
from OOPAO.DeformableMirror import DeformableMirror
from OOPAO.Source import Source
from OOPAO.Telescope import Telescope
from OOPAO.ShackHartmann import ShackHartmann
from tutorials.scao_system.myAoSystem.Imager import Imager  # 导入科学相机模块
import matplotlib.pyplot as plt
import OOPAO.tools.displayTools as tools
# Out:
# ==================================
#      °          *      *
#  ▄██▄   ▄██▄  ▄███▄   ▄██▄ * ▄██▄
# ██* ██ ██  ██ ██  ██ ██  ██ ██  ██
# ██  ██ ██° ██ ██  ██ ██* ██ ██  ██
# ██  ██ ██  ██ ████▀  ██▄▄██ ██  ██
# ██* ██ ██  ██ ██     ██▀▀██ ██  ██
# ██  ██ ██  ██ ██ *   ██  ██ ██* ██
#  ▀██▀   ▀██▀  ██   ° ██  ██  ▀██▀
#       *         *
# ==================================
#
#
# **************************************************************************************************************************************************************
# NUMPY WARNING: mkl blas not found! Multi-threading may not work as expected.
# **************************************************************************************************************************************************************
# 1.26.2

# %%
ngs = Source(magnitude=5,optBand='H')

# 创建望远镜
tel = Telescope(resolution          = 120, # 分辨率
                diameter            = 8, # 直径
                samplingTime        = 1/1000, # 采样时间
                centralObstruction  = 0) # 中心遮挡比例
ngs * tel
atm = Atmosphere(
    telescope=tel,
    r0=0.15,  # 大气湍流的弗里德参数（Fried parameter），表示大气相干长度，单位为米
    L0=30,# 大气湍流的外尺度（Outer scale），单位为米
    altitude=[0,4000,10000],# 每个湍流层的海拔高度，单位为米
    fractionalR0=[0.7,0.25,0.05], # 每个湍流层的 Cn² 剖面，表示每个层对总湍流的贡献比例
    windSpeed=[5,10,20],# 每个湍流层的风速，单位为米/秒
    windDirection=[0,90,360])# 每个湍流层的风向，单位为度
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%% SOURCE %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#  Source Wavelength Zenith  Azimuth   Altitude Magnitude    Flux
#            [m]    [arcsec]  [deg]      [m]              [phot/m2/s]
# -------------------------------------------------------------------
#   NGS   1.654e-06    0        0        inf       5.0    29891304.3
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%% TELESCOPE %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#      Diameter             8                [m]
#     Resolution           120             [pixels]
#     Pixel Size           0.07              [m]
#      Surface             50.0              [m2]
# Central Obstruction        0          [% of diameter]
# Pixels in the pupil      11304            [pixels]
#       Source             None
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# No light propagated through the telescope

# %%
tel-atm
camH = Imager() # 创建科学相机
camH.clock_rate = 1000 # 时钟频率
camH.exposure_time = 0.2 # 曝光时间
camH.relay(tel.src)
camH.reference_frame = camH.frame # 无湍流情况下的图片
camH.display()

# %%
atm.initializeAtmosphere(telescope=tel)
tel+atm
camH.relay(tel.src)
camH.display()
# Out:
# -> Computing the initial phase screen...
# initial phase screen : 0.010144472122192383 s
# ZZt.. : 1.7905609607696533 s
# ZXt.. : 0.2582881450653076 s
# XXt.. : 0.13341259956359863 s
# Done!
# -> Computing the initial phase screen...
# initial phase screen : 0.018450260162353516 s
# ZZt.. : 9.5367431640625e-07 s
# ZXt.. : 2.002716064453125e-05 s
# XXt.. : 9.059906005859375e-06 s
# SCAO system considered: covariance matrices were already computed!
# Done!
# -> Computing the initial phase screen...
# initial phase screen : 0.009908199310302734 s
# ZZt.. : 6.198883056640625e-06 s
# ZXt.. : 2.0265579223632812e-05 s
# XXt.. : 9.298324584960938e-06 s
# SCAO system considered: covariance matrices were already computed!
# Done!

# %%
# print(np.max(camH.frame),np.max(camH.reference_frame))
# print(np.sum(camH.frame/np.max(camH.reference_frame)))
# print(np.sum(camH.frame/np.max(camH.frame)))
# print(np.sum(camH.reference_frame/np.max(camH.reference_frame)))

# %%
camH.strehl
# Out:
# 0.0336169688710269

# %%
# 创建变形镜
dm=DeformableMirror(telescope    = tel,
                    nSubap       = 20, # 沿望远镜直径的变形镜驱动器数，即总驱动数=nSubap*nSubap
                    mechCoupling = 0.1) # 驱动器之间的机械耦合系数,用于描述变形镜的各个驱动器之间的机械相互作用程度
# 创建SH-WFS 

wfs = ShackHartmann(nSubap              = 20, #  沿望远镜直径的子孔径数
                    telescope           = tel,
                    lightRatio          = 0.3, # 用于筛选有效子孔径
                    is_geometric        = False, # 是否启用几何模式（直接测量梯度）
                    threshold_cog       = 0.01) # 计算光斑质心时的阈值
gainCL                  = 0.6  # 传感增益
# Out:
# No coordinates loaded.. taking the cartesian geometry as a default
# Generating a Deformable Mirror:
# Computing the 2D zonal modes...
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%% DEFORMABLE MIRROR %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Controlled Actuators        357
#          M4                False
#         Pitch               0.4               [m]
#  Mechanical Coupling        0.1               [%]
# -------------------------------------------------------------------------------
# Mis-registration:
# Rotation [deg]	Shift X [m]	Shift Y [m]	Radial Scaling [%]	Tangential Scaling [%]
#       0       	     0     	     0     	        0         	          0
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# -------------Detector--------------
# Sensor type              |   CCD
# Resolution [px]          |   120
# Gain                     |    1
# Quantum efficiency [%]   |   100
# Binning                  |   1x1
# Dark current [e-/px/s]   |  0.00
# Photon noise             |  False
# Bkg noise [e-]           |  False
# Readout noise [e-/px]    |   0.0
# -----------------------------------
#
# Selecting valid subapertures based on flux considerations..

# %%
from OOPAO.calibration.ao_calibration import ao_calibration
from tutorials.scao_system.parameter_files.parameterFile_VLT_I_Band_SHWFS import initializeParameterFile

param = initializeParameterFile()

'''
加载或生成模态基,即模式到控制矩阵（M2C）用于将模式映射到变形镜（DM）的控制信号
计算或加载交互矩阵
'''
ao_calib =  ao_calibration(param            = param,\
                           ngs              = ngs,\
                           tel              = tel,\
                           atm              = atm,\
                           dm               = dm,\
                           wfs              = wfs,\
                           nameFolderIntMat = None,\
                           nameIntMat       = None,\
                           nameFolderBasis  = None,\
                           nameBasis        = None,\
                           nMeasurements    = 100)
# Out:
# Reading/Writting calibration data from data_calibration/
# Writting output data in data_cl/
# Loading the KL Modal Basis from: data_calibration/M2C_120_res
# ERROR: No file found! Taking a zonal basis instead..
# Loading Interaction matrix data_calibration/VLT_I_band_20x20/zonal_interaction_matrix_120_res_332_subap_diffractive...
# ERROR: No file found! computing imat..
# Interaction Matrix Computation:
#  25%|██▌       | 1/4 [00:03<00:09,  3.27s/it]
# 100/357
# Time elapsed: 3.2690787315368652 s
#  50%|█████     | 2/4 [00:05<00:05,  2.78s/it]
# 200/357
# Time elapsed: 2.428123712539673 s
#  75%|███████▌  | 3/4 [00:07<00:02,  2.41s/it]
# 300/357
# Time elapsed: 1.9757421016693115 s
# 100%|██████████| 4/4 [00:08<00:00,  2.19s/it]
# 400/357
# Time elapsed: 1.0673704147338867 s
# No Modal Gains found. All gains set to 1

# %%
# 闭环控制
calib_CL    = ao_calib.calib # 交互矩阵
M2C_CL      = ao_calib.M2C

tel+atm
ngs*tel*dm*wfs
# initialize DM commands
dm.coefs=0


param['nLoop'] = 200
# 初始化参数
SR                      = np.zeros(param['nLoop']) # 斯特列尔比
total                   = np.zeros(param['nLoop'])
residual                = np.zeros(param['nLoop'])
wfsSignal               = np.arange(0,wfs.nSignal)*0

wfs.cam.photonNoise = True  # 启用光子噪声
atm.initializeAtmosphere(telescope=tel)
# 分配内存以保存数据
SR = np.zeros(param['nLoop'])  # 斯特列尔比
SR_old = np.zeros(param['nLoop'])  # 近似方式斯特列尔比
total = np.zeros(param['nLoop'])  # 总波前误差
residual = np.zeros(param['nLoop'])  # 残余波前误差
wfsSignal = np.zeros(wfs.nSignal)  # 波前传感器信号

# 初始化变形镜控制信号
dm.coefs = 0
gainCL = 0.6  # 闭环控制增益
# 主循环
for i in range(param['nLoop']):
    start_time = time.time()

    # 更新大气湍流相位屏
    atm.update()
    # tel-atm
    # camH.relay(tel.src)
    # camH.reference_frame = camH.frame
    # tel+atm
    # 记录总的波前误差
    total[i] = np.std(tel.OPD[np.where(tel.pupil > 0)]) * 1e9

    # 光波传播：自然引导星 -> 望远镜 -> 变形镜 -> 波前传感器
    ngs * tel * dm * wfs

    # 更新变形镜控制信号
    dm.coefs = dm.coefs - gainCL * M2C_CL @ calib_CL.M @ wfsSignal

    # 更新波前传感器信号
    wfsSignal = wfs.signal
    # 记录残余波前误差
    residual[i] = np.std(tel.OPD[np.where(tel.pupil > 0)]) * 1e9
    # # 光波传播：自然引导星 -> 望远镜 -> 变形镜 -> 科学相机
    # ngs * tel * dm
    # tel * dm
    camH.relay(tel.src)
    # camH.display()
    # if i % 4 == 0:
    #     camH.display()
        # plt.figure()
        # plt.imshow(tel.src.phase)
        # plt.show()

    SR[i] = camH.strehl  # 科学相机计算的斯特列尔比
    SR_old[i]=np.exp(-np.var(tel.src.phase[np.where(tel.pupil==1)]))


    # 打印结果
    elapsed_time = time.time() - start_time
    print(f'Loop {i+1}/{param["nLoop"]} - Elapsed time: {elapsed_time:.2f} s')
    print(f'Turbulence: {total[i]:.2f} nm -- Residual: {residual[i]:.2f} nm -- SR: {SR[i]:.2f}\n')

ngs*tel * dm
# camH.relay(tel.src)
# camH.display()
# 绘制斯特列尔比随时间的变化

plt.figure()
plt.plot(np.arange(param['nLoop']), SR, label='Strehl Ratio')
plt.plot(np.arange(param['nLoop']), SR_old, label='Strehl Ratio(Approximate approach)')
plt.xlabel('Loop Index')
plt.ylabel('Strehl Ratio')
plt.title(  f"gainCL={gainCL:.2f}, "
            f"samplingTime={tel.samplingTime:.3f}s\n"
            f"exposure_time={camH.exposure_time:.3f}s, "
            f"clock_rate={camH.clock_rate:.0f}Hz")
plt.legend()
plt.grid()
plt.show()
# Out:
# Loop 1/200 - Elapsed time: 0.05 s
# Turbulence: 772.89 nm -- Residual: 772.89 nm -- SR: 0.03
#
# Loop 2/200 - Elapsed time: 0.06 s
# Turbulence: 773.62 nm -- Residual: 773.62 nm -- SR: 0.04
#
# Loop 3/200 - Elapsed time: 0.07 s
# Turbulence: 774.36 nm -- Residual: 390.45 nm -- SR: 0.18
#
# Loop 4/200 - Elapsed time: 0.06 s
# Turbulence: 775.12 nm -- Residual: 128.15 nm -- SR: 0.79
#
# Loop 5/200 - Elapsed time: 0.06 s
# Turbulence: 775.92 nm -- Residual: 239.31 nm -- SR: 0.43
#
# Loop 6/200 - Elapsed time: 0.07 s
# Turbulence: 776.72 nm -- Residual: 190.77 nm -- SR: 0.59
#
# Loop 7/200 - Elapsed time: 0.06 s
# Turbulence: 777.46 nm -- Residual: 128.24 nm -- SR: 0.79
#
# Loop 8/200 - Elapsed time: 0.06 s
# Turbulence: 778.22 nm -- Residual: 194.35 nm -- SR: 0.58
#
# Loop 9/200 - Elapsed time: 0.06 s
# Turbulence: 779.01 nm -- Residual: 218.06 nm -- SR: 0.50
#
# Loop 10/200 - Elapsed time: 0.06 s
# Turbulence: 779.80 nm -- Residual: 183.23 nm -- SR: 0.61
#
# Loop 11/200 - Elapsed time: 0.06 s
# Turbulence: 780.61 nm -- Residual: 139.81 nm -- SR: 0.75
#
# Loop 12/200 - Elapsed time: 0.06 s
# Turbulence: 781.43 nm -- Residual: 128.02 nm -- SR: 0.79
#
# Loop 13/200 - Elapsed time: 0.07 s
# Turbulence: 782.18 nm -- Residual: 129.57 nm -- SR: 0.79
#
# Loop 14/200 - Elapsed time: 0.06 s
# Turbulence: 782.87 nm -- Residual: 133.71 nm -- SR: 0.77
#
# Loop 15/200 - Elapsed time: 0.06 s
# Turbulence: 783.57 nm -- Residual: 144.68 nm -- SR: 0.74
#
# Loop 16/200 - Elapsed time: 0.06 s
# Turbulence: 784.29 nm -- Residual: 148.39 nm -- SR: 0.73
#
# Loop 17/200 - Elapsed time: 0.06 s
# Turbulence: 785.04 nm -- Residual: 146.67 nm -- SR: 0.73
#
# Loop 18/200 - Elapsed time: 0.07 s
# Turbulence: 785.83 nm -- Residual: 140.95 nm -- SR: 0.75
#
# Loop 19/200 - Elapsed time: 0.08 s
# Turbulence: 786.66 nm -- Residual: 137.00 nm -- SR: 0.76
#
# Loop 20/200 - Elapsed time: 0.06 s
# Turbulence: 787.42 nm -- Residual: 134.48 nm -- SR: 0.77
#
# Loop 21/200 - Elapsed time: 0.06 s
# Turbulence: 788.18 nm -- Residual: 132.92 nm -- SR: 0.78
#
# Loop 22/200 - Elapsed time: 0.06 s
# Turbulence: 788.99 nm -- Residual: 135.60 nm -- SR: 0.77
#
# Loop 23/200 - Elapsed time: 0.06 s
# Turbulence: 789.81 nm -- Residual: 138.53 nm -- SR: 0.76
#
# Loop 24/200 - Elapsed time: 0.06 s
# Turbulence: 790.64 nm -- Residual: 140.88 nm -- SR: 0.75
#
# Loop 25/200 - Elapsed time: 0.06 s
# Turbulence: 791.50 nm -- Residual: 140.56 nm -- SR: 0.75
#
# Loop 26/200 - Elapsed time: 0.07 s
# Turbulence: 792.31 nm -- Residual: 141.20 nm -- SR: 0.75
#
# Loop 27/200 - Elapsed time: 0.06 s
# Turbulence: 793.06 nm -- Residual: 139.73 nm -- SR: 0.75
#
# Loop 28/200 - Elapsed time: 0.06 s
# Turbulence: 793.81 nm -- Residual: 134.26 nm -- SR: 0.77
#
# Loop 29/200 - Elapsed time: 0.06 s
# Turbulence: 794.57 nm -- Residual: 131.55 nm -- SR: 0.78
#
# Loop 30/200 - Elapsed time: 0.06 s
# Turbulence: 795.32 nm -- Residual: 132.07 nm -- SR: 0.78
#
# Loop 31/200 - Elapsed time: 0.05 s
# Turbulence: 796.10 nm -- Residual: 131.99 nm -- SR: 0.78
#
# Loop 32/200 - Elapsed time: 0.05 s
# Turbulence: 796.91 nm -- Residual: 134.30 nm -- SR: 0.77
#
# Loop 33/200 - Elapsed time: 0.05 s
# Turbulence: 797.67 nm -- Residual: 135.46 nm -- SR: 0.77
#
# Loop 34/200 - Elapsed time: 0.05 s
# Turbulence: 798.38 nm -- Residual: 135.95 nm -- SR: 0.77
#
# Loop 35/200 - Elapsed time: 0.06 s
# Turbulence: 799.12 nm -- Residual: 139.45 nm -- SR: 0.76
#
# Loop 36/200 - Elapsed time: 0.05 s
# Turbulence: 799.87 nm -- Residual: 146.47 nm -- SR: 0.73
#
# Loop 37/200 - Elapsed time: 0.05 s
# Turbulence: 800.61 nm -- Residual: 149.81 nm -- SR: 0.72
#
# Loop 38/200 - Elapsed time: 0.05 s
# Turbulence: 801.37 nm -- Residual: 150.91 nm -- SR: 0.72
#
# Loop 39/200 - Elapsed time: 0.05 s
# Turbulence: 802.12 nm -- Residual: 155.83 nm -- SR: 0.70
#
# Loop 40/200 - Elapsed time: 0.05 s
# Turbulence: 802.76 nm -- Residual: 158.60 nm -- SR: 0.69
#
# Loop 41/200 - Elapsed time: 0.05 s
# Turbulence: 803.37 nm -- Residual: 158.32 nm -- SR: 0.70
#
# Loop 42/200 - Elapsed time: 0.05 s
# Turbulence: 803.99 nm -- Residual: 159.19 nm -- SR: 0.69
#
# Loop 43/200 - Elapsed time: 0.05 s
# Turbulence: 804.61 nm -- Residual: 159.16 nm -- SR: 0.69
#
# Loop 44/200 - Elapsed time: 0.05 s
# Turbulence: 805.24 nm -- Residual: 153.62 nm -- SR: 0.71
#
# Loop 45/200 - Elapsed time: 0.05 s
# Turbulence: 805.90 nm -- Residual: 146.07 nm -- SR: 0.74
#
# Loop 46/200 - Elapsed time: 0.05 s
# Turbulence: 806.55 nm -- Residual: 141.93 nm -- SR: 0.75
#
# Loop 47/200 - Elapsed time: 0.05 s
# Turbulence: 807.12 nm -- Residual: 140.97 nm -- SR: 0.75
#
# Loop 48/200 - Elapsed time: 0.05 s
# Turbulence: 807.70 nm -- Residual: 140.85 nm -- SR: 0.75
#
# Loop 49/200 - Elapsed time: 0.05 s
# Turbulence: 808.30 nm -- Residual: 141.02 nm -- SR: 0.75
#
# Loop 50/200 - Elapsed time: 0.05 s
# Turbulence: 808.89 nm -- Residual: 139.75 nm -- SR: 0.76
#
# Loop 51/200 - Elapsed time: 0.05 s
# Turbulence: 809.47 nm -- Residual: 141.42 nm -- SR: 0.75
#
# Loop 52/200 - Elapsed time: 0.05 s
# Turbulence: 810.05 nm -- Residual: 140.77 nm -- SR: 0.75
#
# Loop 53/200 - Elapsed time: 0.05 s
# Turbulence: 810.53 nm -- Residual: 146.96 nm -- SR: 0.73
#
# Loop 54/200 - Elapsed time: 0.05 s
# Turbulence: 810.93 nm -- Residual: 147.57 nm -- SR: 0.73
#
# Loop 55/200 - Elapsed time: 0.05 s
# Turbulence: 811.31 nm -- Residual: 144.32 nm -- SR: 0.74
#
# Loop 56/200 - Elapsed time: 0.05 s
# Turbulence: 811.70 nm -- Residual: 141.77 nm -- SR: 0.75
#
# Loop 57/200 - Elapsed time: 0.05 s
# Turbulence: 812.07 nm -- Residual: 137.78 nm -- SR: 0.76
#
# Loop 58/200 - Elapsed time: 0.05 s
# Turbulence: 812.46 nm -- Residual: 136.99 nm -- SR: 0.76
#
# Loop 59/200 - Elapsed time: 0.05 s
# Turbulence: 812.86 nm -- Residual: 136.69 nm -- SR: 0.76
#
# Loop 60/200 - Elapsed time: 0.05 s
# Turbulence: 813.16 nm -- Residual: 137.56 nm -- SR: 0.76
#
# Loop 61/200 - Elapsed time: 0.05 s
# Turbulence: 813.44 nm -- Residual: 137.37 nm -- SR: 0.76
#
# Loop 62/200 - Elapsed time: 0.05 s
# Turbulence: 813.74 nm -- Residual: 138.00 nm -- SR: 0.76
#
# Loop 63/200 - Elapsed time: 0.05 s
# Turbulence: 814.03 nm -- Residual: 137.54 nm -- SR: 0.76
#
# Loop 64/200 - Elapsed time: 0.05 s
# Turbulence: 814.31 nm -- Residual: 135.27 nm -- SR: 0.77
#
# Loop 65/200 - Elapsed time: 0.05 s
# Turbulence: 814.59 nm -- Residual: 134.87 nm -- SR: 0.77
#
# Loop 66/200 - Elapsed time: 0.06 s
# Turbulence: 814.82 nm -- Residual: 135.19 nm -- SR: 0.77
#
# Loop 67/200 - Elapsed time: 0.05 s
# Turbulence: 814.95 nm -- Residual: 138.41 nm -- SR: 0.76
#
# Loop 68/200 - Elapsed time: 0.05 s
# Turbulence: 815.06 nm -- Residual: 140.42 nm -- SR: 0.75
#
# Loop 69/200 - Elapsed time: 0.05 s
# Turbulence: 815.19 nm -- Residual: 137.75 nm -- SR: 0.76
#
# Loop 70/200 - Elapsed time: 0.05 s
# Turbulence: 815.29 nm -- Residual: 133.59 nm -- SR: 0.77
#
# Loop 71/200 - Elapsed time: 0.05 s
# Turbulence: 815.42 nm -- Residual: 136.66 nm -- SR: 0.77
#
# Loop 72/200 - Elapsed time: 0.05 s
# Turbulence: 815.57 nm -- Residual: 141.40 nm -- SR: 0.75
#
# Loop 73/200 - Elapsed time: 0.05 s
# Turbulence: 815.67 nm -- Residual: 145.42 nm -- SR: 0.74
#
# Loop 74/200 - Elapsed time: 0.05 s
# Turbulence: 815.72 nm -- Residual: 146.33 nm -- SR: 0.74
#
# Loop 75/200 - Elapsed time: 0.05 s
# Turbulence: 815.79 nm -- Residual: 146.47 nm -- SR: 0.73
#
# Loop 76/200 - Elapsed time: 0.05 s
# Turbulence: 815.89 nm -- Residual: 146.30 nm -- SR: 0.73
#
# Loop 77/200 - Elapsed time: 0.05 s
# Turbulence: 815.98 nm -- Residual: 146.97 nm -- SR: 0.73
#
# Loop 78/200 - Elapsed time: 0.05 s
# Turbulence: 816.08 nm -- Residual: 150.31 nm -- SR: 0.72
#
# Loop 79/200 - Elapsed time: 0.05 s
# Turbulence: 816.17 nm -- Residual: 154.42 nm -- SR: 0.71
#
# Loop 80/200 - Elapsed time: 0.05 s
# Turbulence: 816.16 nm -- Residual: 160.82 nm -- SR: 0.69
#
# Loop 81/200 - Elapsed time: 0.05 s
# Turbulence: 816.12 nm -- Residual: 161.14 nm -- SR: 0.69
#
# Loop 82/200 - Elapsed time: 0.05 s
# Turbulence: 816.09 nm -- Residual: 154.71 nm -- SR: 0.71
#
# Loop 83/200 - Elapsed time: 0.05 s
# Turbulence: 816.06 nm -- Residual: 149.49 nm -- SR: 0.73
#
# Loop 84/200 - Elapsed time: 0.05 s
# Turbulence: 816.03 nm -- Residual: 147.87 nm -- SR: 0.73
#
# Loop 85/200 - Elapsed time: 0.05 s
# Turbulence: 816.03 nm -- Residual: 151.99 nm -- SR: 0.72
#
# Loop 86/200 - Elapsed time: 0.05 s
# Turbulence: 816.02 nm -- Residual: 154.23 nm -- SR: 0.71
#
# Loop 87/200 - Elapsed time: 0.05 s
# Turbulence: 815.94 nm -- Residual: 150.16 nm -- SR: 0.72
#
# Loop 88/200 - Elapsed time: 0.05 s
# Turbulence: 815.87 nm -- Residual: 151.95 nm -- SR: 0.72
#
# Loop 89/200 - Elapsed time: 0.05 s
# Turbulence: 815.83 nm -- Residual: 159.61 nm -- SR: 0.69
#
# Loop 90/200 - Elapsed time: 0.05 s
# Turbulence: 815.77 nm -- Residual: 161.13 nm -- SR: 0.69
#
# Loop 91/200 - Elapsed time: 0.05 s
# Turbulence: 815.72 nm -- Residual: 162.00 nm -- SR: 0.69
#
# Loop 92/200 - Elapsed time: 0.05 s
# Turbulence: 815.68 nm -- Residual: 161.94 nm -- SR: 0.69
#
# Loop 93/200 - Elapsed time: 0.06 s
# Turbulence: 815.56 nm -- Residual: 160.73 nm -- SR: 0.69
#
# Loop 94/200 - Elapsed time: 0.05 s
# Turbulence: 815.39 nm -- Residual: 159.16 nm -- SR: 0.69
#
# Loop 95/200 - Elapsed time: 0.05 s
# Turbulence: 815.21 nm -- Residual: 151.28 nm -- SR: 0.72
#
# Loop 96/200 - Elapsed time: 0.05 s
# Turbulence: 815.05 nm -- Residual: 151.11 nm -- SR: 0.72
#
# Loop 97/200 - Elapsed time: 0.05 s
# Turbulence: 814.88 nm -- Residual: 154.78 nm -- SR: 0.71
#
# Loop 98/200 - Elapsed time: 0.05 s
# Turbulence: 814.74 nm -- Residual: 157.86 nm -- SR: 0.70
#
# Loop 99/200 - Elapsed time: 0.05 s
# Turbulence: 814.61 nm -- Residual: 160.02 nm -- SR: 0.69
#
# Loop 100/200 - Elapsed time: 0.05 s
# Turbulence: 814.42 nm -- Residual: 157.40 nm -- SR: 0.70
#
# Loop 101/200 - Elapsed time: 0.05 s
# Turbulence: 814.22 nm -- Residual: 156.45 nm -- SR: 0.71
#
# Loop 102/200 - Elapsed time: 0.05 s
# Turbulence: 814.05 nm -- Residual: 150.56 nm -- SR: 0.72
#
# Loop 103/200 - Elapsed time: 0.05 s
# Turbulence: 813.88 nm -- Residual: 146.25 nm -- SR: 0.74
#
# Loop 104/200 - Elapsed time: 0.05 s
# Turbulence: 813.72 nm -- Residual: 144.40 nm -- SR: 0.74
#
# Loop 105/200 - Elapsed time: 0.05 s
# Turbulence: 813.57 nm -- Residual: 144.90 nm -- SR: 0.74
#
# Loop 106/200 - Elapsed time: 0.05 s
# Turbulence: 813.38 nm -- Residual: 145.96 nm -- SR: 0.74
#
# Loop 107/200 - Elapsed time: 0.05 s
# Turbulence: 813.10 nm -- Residual: 144.04 nm -- SR: 0.74
#
# Loop 108/200 - Elapsed time: 0.05 s
# Turbulence: 812.81 nm -- Residual: 145.43 nm -- SR: 0.74
#
# Loop 109/200 - Elapsed time: 0.05 s
# Turbulence: 812.55 nm -- Residual: 146.47 nm -- SR: 0.74
#
# Loop 110/200 - Elapsed time: 0.05 s
# Turbulence: 812.29 nm -- Residual: 150.26 nm -- SR: 0.72
#
# Loop 111/200 - Elapsed time: 0.05 s
# Turbulence: 812.05 nm -- Residual: 145.83 nm -- SR: 0.74
#
# Loop 112/200 - Elapsed time: 0.05 s
# Turbulence: 811.83 nm -- Residual: 135.37 nm -- SR: 0.77
#
# Loop 113/200 - Elapsed time: 0.06 s
# Turbulence: 811.58 nm -- Residual: 128.98 nm -- SR: 0.79
#
# Loop 114/200 - Elapsed time: 0.05 s
# Turbulence: 811.30 nm -- Residual: 128.39 nm -- SR: 0.79
#
# Loop 115/200 - Elapsed time: 0.05 s
# Turbulence: 811.06 nm -- Residual: 136.63 nm -- SR: 0.77
#
# Loop 116/200 - Elapsed time: 0.05 s
# Turbulence: 810.83 nm -- Residual: 141.90 nm -- SR: 0.75
#
# Loop 117/200 - Elapsed time: 0.05 s
# Turbulence: 810.60 nm -- Residual: 139.58 nm -- SR: 0.76
#
# Loop 118/200 - Elapsed time: 0.05 s
# Turbulence: 810.37 nm -- Residual: 137.20 nm -- SR: 0.77
#
# Loop 119/200 - Elapsed time: 0.05 s
# Turbulence: 810.10 nm -- Residual: 133.05 nm -- SR: 0.78
#
# Loop 120/200 - Elapsed time: 0.05 s
# Turbulence: 809.75 nm -- Residual: 130.66 nm -- SR: 0.78
#
# Loop 121/200 - Elapsed time: 0.05 s
# Turbulence: 809.35 nm -- Residual: 130.08 nm -- SR: 0.79
#
# Loop 122/200 - Elapsed time: 0.05 s
# Turbulence: 808.97 nm -- Residual: 130.38 nm -- SR: 0.79
#
# Loop 123/200 - Elapsed time: 0.05 s
# Turbulence: 808.57 nm -- Residual: 133.90 nm -- SR: 0.78
#
# Loop 124/200 - Elapsed time: 0.05 s
# Turbulence: 808.18 nm -- Residual: 135.14 nm -- SR: 0.77
#
# Loop 125/200 - Elapsed time: 0.05 s
# Turbulence: 807.81 nm -- Residual: 135.33 nm -- SR: 0.77
#
# Loop 126/200 - Elapsed time: 0.05 s
# Turbulence: 807.41 nm -- Residual: 136.30 nm -- SR: 0.77
#
# Loop 127/200 - Elapsed time: 0.05 s
# Turbulence: 806.98 nm -- Residual: 136.42 nm -- SR: 0.77
#
# Loop 128/200 - Elapsed time: 0.05 s
# Turbulence: 806.56 nm -- Residual: 133.94 nm -- SR: 0.77
#
# Loop 129/200 - Elapsed time: 0.05 s
# Turbulence: 806.15 nm -- Residual: 132.66 nm -- SR: 0.78
#
# Loop 130/200 - Elapsed time: 0.05 s
# Turbulence: 805.73 nm -- Residual: 136.59 nm -- SR: 0.77
#
# Loop 131/200 - Elapsed time: 0.05 s
# Turbulence: 805.31 nm -- Residual: 137.67 nm -- SR: 0.76
#
# Loop 132/200 - Elapsed time: 0.05 s
# Turbulence: 804.85 nm -- Residual: 134.64 nm -- SR: 0.77
#
# Loop 133/200 - Elapsed time: 0.05 s
# Turbulence: 804.31 nm -- Residual: 133.01 nm -- SR: 0.78
#
# Loop 134/200 - Elapsed time: 0.05 s
# Turbulence: 803.72 nm -- Residual: 133.52 nm -- SR: 0.77
#
# Loop 135/200 - Elapsed time: 0.05 s
# Turbulence: 803.11 nm -- Residual: 134.90 nm -- SR: 0.77
#
# Loop 136/200 - Elapsed time: 0.05 s
# Turbulence: 802.51 nm -- Residual: 135.24 nm -- SR: 0.77
#
# Loop 137/200 - Elapsed time: 0.05 s
# Turbulence: 801.91 nm -- Residual: 134.24 nm -- SR: 0.77
#
# Loop 138/200 - Elapsed time: 0.05 s
# Turbulence: 801.32 nm -- Residual: 132.36 nm -- SR: 0.78
#
# Loop 139/200 - Elapsed time: 0.05 s
# Turbulence: 800.72 nm -- Residual: 129.27 nm -- SR: 0.79
#
# Loop 140/200 - Elapsed time: 0.05 s
# Turbulence: 800.07 nm -- Residual: 128.60 nm -- SR: 0.79
#
# Loop 141/200 - Elapsed time: 0.06 s
# Turbulence: 799.41 nm -- Residual: 131.37 nm -- SR: 0.78
#
# Loop 142/200 - Elapsed time: 0.06 s
# Turbulence: 798.78 nm -- Residual: 137.12 nm -- SR: 0.76
#
# Loop 143/200 - Elapsed time: 0.06 s
# Turbulence: 798.14 nm -- Residual: 139.72 nm -- SR: 0.76
#
# Loop 144/200 - Elapsed time: 0.06 s
# Turbulence: 797.48 nm -- Residual: 143.72 nm -- SR: 0.74
#
# Loop 145/200 - Elapsed time: 0.06 s
# Turbulence: 796.81 nm -- Residual: 141.89 nm -- SR: 0.75
#
# Loop 146/200 - Elapsed time: 0.07 s
# Turbulence: 796.09 nm -- Residual: 136.85 nm -- SR: 0.76
#
# Loop 147/200 - Elapsed time: 0.06 s
# Turbulence: 795.33 nm -- Residual: 133.95 nm -- SR: 0.77
#
# Loop 148/200 - Elapsed time: 0.06 s
# Turbulence: 794.56 nm -- Residual: 137.45 nm -- SR: 0.76
#
# Loop 149/200 - Elapsed time: 0.06 s
# Turbulence: 793.80 nm -- Residual: 140.41 nm -- SR: 0.75
#
# Loop 150/200 - Elapsed time: 0.06 s
# Turbulence: 793.05 nm -- Residual: 136.77 nm -- SR: 0.76
#
# Loop 151/200 - Elapsed time: 0.06 s
# Turbulence: 792.31 nm -- Residual: 135.26 nm -- SR: 0.77
#
# Loop 152/200 - Elapsed time: 0.06 s
# Turbulence: 791.58 nm -- Residual: 132.15 nm -- SR: 0.78
#
# Loop 153/200 - Elapsed time: 0.07 s
# Turbulence: 790.83 nm -- Residual: 133.82 nm -- SR: 0.77
#
# Loop 154/200 - Elapsed time: 0.06 s
# Turbulence: 790.09 nm -- Residual: 137.49 nm -- SR: 0.76
#
# Loop 155/200 - Elapsed time: 0.06 s
# Turbulence: 789.39 nm -- Residual: 140.25 nm -- SR: 0.75
#
# Loop 156/200 - Elapsed time: 0.06 s
# Turbulence: 788.70 nm -- Residual: 143.31 nm -- SR: 0.74
#
# Loop 157/200 - Elapsed time: 0.06 s
# Turbulence: 788.00 nm -- Residual: 148.75 nm -- SR: 0.73
#
# Loop 158/200 - Elapsed time: 0.07 s
# Turbulence: 787.29 nm -- Residual: 154.98 nm -- SR: 0.71
#
# Loop 159/200 - Elapsed time: 0.08 s
# Turbulence: 786.53 nm -- Residual: 156.16 nm -- SR: 0.70
#
# Loop 160/200 - Elapsed time: 0.08 s
# Turbulence: 785.73 nm -- Residual: 156.03 nm -- SR: 0.71
#
# Loop 161/200 - Elapsed time: 0.08 s
# Turbulence: 784.90 nm -- Residual: 154.24 nm -- SR: 0.71
#
# Loop 162/200 - Elapsed time: 0.08 s
# Turbulence: 784.09 nm -- Residual: 152.30 nm -- SR: 0.72
#
# Loop 163/200 - Elapsed time: 0.07 s
# Turbulence: 783.27 nm -- Residual: 150.35 nm -- SR: 0.72
#
# Loop 164/200 - Elapsed time: 0.06 s
# Turbulence: 782.45 nm -- Residual: 152.78 nm -- SR: 0.71
#
# Loop 165/200 - Elapsed time: 0.06 s
# Turbulence: 781.62 nm -- Residual: 159.54 nm -- SR: 0.69
#
# Loop 166/200 - Elapsed time: 0.07 s
# Turbulence: 780.76 nm -- Residual: 160.18 nm -- SR: 0.69
#
# Loop 167/200 - Elapsed time: 0.06 s
# Turbulence: 779.91 nm -- Residual: 152.34 nm -- SR: 0.72
#
# Loop 168/200 - Elapsed time: 0.06 s
# Turbulence: 779.09 nm -- Residual: 148.79 nm -- SR: 0.73
#
# Loop 169/200 - Elapsed time: 0.06 s
# Turbulence: 778.29 nm -- Residual: 153.37 nm -- SR: 0.71
#
# Loop 170/200 - Elapsed time: 0.06 s
# Turbulence: 777.49 nm -- Residual: 164.49 nm -- SR: 0.68
#
# Loop 171/200 - Elapsed time: 0.06 s
# Turbulence: 776.67 nm -- Residual: 174.78 nm -- SR: 0.64
#
# Loop 172/200 - Elapsed time: 0.06 s
# Turbulence: 775.80 nm -- Residual: 181.62 nm -- SR: 0.62
#
# Loop 173/200 - Elapsed time: 0.07 s
# Turbulence: 774.88 nm -- Residual: 182.94 nm -- SR: 0.62
#
# Loop 174/200 - Elapsed time: 0.06 s
# Turbulence: 773.94 nm -- Residual: 174.70 nm -- SR: 0.64
#
# Loop 175/200 - Elapsed time: 0.06 s
# Turbulence: 773.00 nm -- Residual: 174.15 nm -- SR: 0.65
#
# Loop 176/200 - Elapsed time: 0.05 s
# Turbulence: 772.07 nm -- Residual: 171.96 nm -- SR: 0.65
#
# Loop 177/200 - Elapsed time: 0.05 s
# Turbulence: 771.13 nm -- Residual: 166.44 nm -- SR: 0.67
#
# Loop 178/200 - Elapsed time: 0.05 s
# Turbulence: 770.18 nm -- Residual: 162.25 nm -- SR: 0.69
#
# Loop 179/200 - Elapsed time: 0.05 s
# Turbulence: 769.21 nm -- Residual: 162.34 nm -- SR: 0.68
#
# Loop 180/200 - Elapsed time: 0.05 s
# Turbulence: 768.25 nm -- Residual: 168.86 nm -- SR: 0.66
#
# Loop 181/200 - Elapsed time: 0.05 s
# Turbulence: 767.30 nm -- Residual: 174.75 nm -- SR: 0.64
#
# Loop 182/200 - Elapsed time: 0.05 s
# Turbulence: 766.40 nm -- Residual: 177.89 nm -- SR: 0.63
#
# Loop 183/200 - Elapsed time: 0.06 s
# Turbulence: 765.49 nm -- Residual: 175.62 nm -- SR: 0.64
#
# Loop 184/200 - Elapsed time: 0.06 s
# Turbulence: 764.58 nm -- Residual: 176.76 nm -- SR: 0.63
#
# Loop 185/200 - Elapsed time: 0.06 s
# Turbulence: 763.64 nm -- Residual: 174.43 nm -- SR: 0.64
#
# Loop 186/200 - Elapsed time: 0.05 s
# Turbulence: 762.65 nm -- Residual: 166.41 nm -- SR: 0.67
#
# Loop 187/200 - Elapsed time: 0.05 s
# Turbulence: 761.65 nm -- Residual: 165.22 nm -- SR: 0.67
#
# Loop 188/200 - Elapsed time: 0.05 s
# Turbulence: 760.66 nm -- Residual: 171.80 nm -- SR: 0.65
#
# Loop 189/200 - Elapsed time: 0.05 s
# Turbulence: 759.70 nm -- Residual: 177.21 nm -- SR: 0.63
#
# Loop 190/200 - Elapsed time: 0.05 s
# Turbulence: 758.72 nm -- Residual: 182.78 nm -- SR: 0.62
#
# Loop 191/200 - Elapsed time: 0.05 s
# Turbulence: 757.76 nm -- Residual: 180.42 nm -- SR: 0.62
#
# Loop 192/200 - Elapsed time: 0.05 s
# Turbulence: 756.77 nm -- Residual: 187.89 nm -- SR: 0.60
#
# Loop 193/200 - Elapsed time: 0.05 s
# Turbulence: 755.76 nm -- Residual: 190.79 nm -- SR: 0.59
#
# Loop 194/200 - Elapsed time: 0.05 s
# Turbulence: 754.75 nm -- Residual: 189.69 nm -- SR: 0.59
#
# Loop 195/200 - Elapsed time: 0.05 s
# Turbulence: 753.78 nm -- Residual: 181.53 nm -- SR: 0.62
#
# Loop 196/200 - Elapsed time: 0.05 s
# Turbulence: 752.82 nm -- Residual: 184.01 nm -- SR: 0.61
#
# Loop 197/200 - Elapsed time: 0.05 s
# Turbulence: 751.83 nm -- Residual: 190.89 nm -- SR: 0.59
#
# Loop 198/200 - Elapsed time: 0.05 s
# Turbulence: 750.81 nm -- Residual: 199.37 nm -- SR: 0.56
#
# Loop 199/200 - Elapsed time: 0.05 s
# Turbulence: 749.73 nm -- Residual: 203.36 nm -- SR: 0.55
#
# Loop 200/200 - Elapsed time: 0.05 s
# Turbulence: 748.66 nm -- Residual: 202.87 nm -- SR: 0.55
